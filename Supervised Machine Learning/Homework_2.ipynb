# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2-A

# %%
titanic_df = pd.read_csv("titanic.csv")
titanic_df.shape
# Out:
# (1309, 14)

# %%
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  siblings_spouses  parents_children  ticket      fare  \
# ...

# %% [markdown]
# # 2-B

# %%
titanic_df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_df.rename(columns = {'sibsp':'siblings_spouses', 'parch':'parents_children'}, 
                  inplace=True)

# %%
titanic_df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'siblings_spouses',
#        'parents_children', 'ticket', 'fare', 'cabin', 'embarked', 'boat',
#        'body', 'home.dest'],
#       dtype='object')

# %%
assert set(['siblings_spouses','parents_children']).issubset(
    titanic_df.columns
), "Columns names were not changed properly"
print("Success")
# Out:
# Success

# %% [markdown]
# # 2-C

# %%
titanic_df['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
type(titanic_df['age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series is returned.

# %% [markdown]
# # 2-D

# %%
titanic_df[['age']]
# Out:
#           age
# 0     29.0000
# 1      0.9167
# 2      2.0000
# 3     30.0000
# 4     25.0000
# ...       ...
# 1304  14.5000
# 1305      NaN
# 1306  26.5000
# 1307  27.0000
# 1308  29.0000
#
# [1309 rows x 1 columns]

# %%
type(titanic_df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  Dataframe is returned.

# %% [markdown]
# # 2-E

# %%
titanic_df[['pclass','survived','age']]
# Out:
#       pclass  survived      age
# 0          1         1  29.0000
# 1          1         1   0.9167
# 2          1         0   2.0000
# 3          1         0  30.0000
# 4          1         0  25.0000
# ...      ...       ...      ...
# 1304       3         0  14.5000
# 1305       3         0      NaN
# 1306       3         0  26.5000
# 1307       3         0  27.0000
# 1308       3         0  29.0000
#
# [1309 rows x 3 columns]

# %% [markdown]
# # 2-F

# %%
titanic_df.iloc[:5,2:5]
# Out:
#                                               name     sex      age
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1                   Allison, Master. Hudson Trevor    male   0.9167
# 2                     Allison, Miss. Helen Loraine  female   2.0000
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000

# %% [markdown]
# # 2-G

# %%
titanic_df.loc[:4,['name', 'sex', 'age']]
# Out:
#                                               name     sex      age
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1                   Allison, Master. Hudson Trevor    male   0.9167
# 2                     Allison, Miss. Helen Loraine  female   2.0000
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000

# %% [markdown]
# # 2-H

# %%
titanic_df['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
survive = titanic_df['survived'].value_counts()[1]
print(survive,"Passengers survived.")
# Out:
# 500 Passengers survived.

# %% [markdown]
# # 2-I

# %%
titanic_df[[titanic_df.survived == 1] and titanic_df.age > 60 ]
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 9          1         0                            Artagaveytia, Mr. Ramon
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 81         1         0                       Crosby, Capt. Edward Gifford
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 115        1         0                                  Fortune, Mr. Mark
# 135        1         0                          Goldschmidt, Mr. George B
# 205        1         0                          Millet, Mr. Francis Davis
# 217        1         0                       Nicholson, Mr. Arthur Ernest
# 221        1         0                     Ostby, Mr. Engelhart Cornelius
# ...

# %%
ans = titanic_df[[titanic_df.survived == 1] and titanic_df.age > 60 ].shape[0]
print(ans,"Passengers survived were over 60.")
# Out:
# 33 Passengers survived were over 60.

# %% [markdown]
# # 2-J

# %%
highest = titanic_df['fare'].max()
lowest = titanic_df['fare'].min()

# %%
print("Highest Fare is :", highest)
print("Lowest Fare is :", lowest)
# Out:
# Highest Fare is : 512.3292
# Lowest Fare is : 0.0

# %% [markdown]
# # 2-K

# %%
titanic_df.sort_values(by='fare', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 183        1         1                             Lesurer, Mr. Gustave J
# 302        1         1                                   Ward, Miss. Anna
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 113        1         1                         Fortune, Miss. Mabel Helen
# ...      ...       ...                                                ...
# 363        2         0                              Campbell, Mr. William
# 384        2         0                     Cunningham, Mr. Alfred Fleming
# 581        2         0                         Watson, Mr. Ennis Hastings
# 410        2         0                   Frost, Mr. Anthony Wood "Archie"
# 1225       3         0                                 Storey, Mr. Thomas
#
#          sex   age  siblings_spouses  parents_children    ticket      fare  \
# ...

# %% [markdown]
# # 2-L

# %%
# df_csv = titanic_df.sort_values(by='fare', ascending=False)
# df_csv.to_csv('titanic_fares.csv')

# %% [markdown]
# # 2-M

# %%
plt.scatter(titanic_df['age'],titanic_df['fare'], color = 'red')
plt.show()

# %% [markdown]
# # 2-N

# %%
sns.countplot(x='embarked', data = titanic_df, color='m')
plt.xlabel("Embark")
plt.ylabel("No Of Pasengers")
plt.title("Passengers From Each Port")
plt.show()
